# %% [markdown]
# <a href="https://colab.research.google.com/github/IIbitoye/FDSfE_IIbitoye/blob/main/HW2/Ite'sHW2_happiness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import missingno as msno
import pylab as pl

# %%
happiness=pd.read_csv("https://github.com/fedhere/FDSfE_FBianco/raw/main/data/happines.csv")
happiness
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
# 158      Namibia                              NaN            4.639
# 159       Gambia                              NaN            4.516
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
happiness.shape
# Out:
# (160, 12)

# %% [markdown]
# This shows the shape of the dataframe

# %%
print("The shape of this happiness dataframe is " + format(happiness.shape) )
# Out:
# The shape of this happiness dataframe is (160, 12)

# %%
happiness.head(10)
# Out:
#        Country                     Region  Happiness Score  Standard Error  \
# 0  Switzerland             Western Europe            7.587         0.03411
# 1      Iceland             Western Europe            7.561         0.04884
# 2      Denmark             Western Europe            7.527         0.03328
# 3       Norway             Western Europe            7.522         0.03880
# 4       Canada              North America            7.427         0.03553
# 5      Finland             Western Europe            7.406         0.03140
# 6  Netherlands             Western Europe            7.378         0.02799
# 7       Sweden             Western Europe            7.364         0.03157
# 8  New Zealand  Australia and New Zealand            7.286         0.03371
# 9    Australia  Australia and New Zealand            7.284         0.04083
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# This prints out the first 10 rows of our dataset

# %%
happiness.tail(10)
# Out:
#           Country                           Region  Happiness Score  \
# 150   Ivory Coast               Sub-Saharan Africa            3.655
# 151  Burkina Faso               Sub-Saharan Africa            3.587
# 152   Afghanistan                    Southern Asia            3.575
# 153        Rwanda               Sub-Saharan Africa            3.465
# 154         Benin               Sub-Saharan Africa            3.340
# 155         Syria  Middle East and Northern Africa            3.006
# 156       Burundi               Sub-Saharan Africa            2.905
# 157          Togo               Sub-Saharan Africa            2.839
# 158       Namibia                              NaN            4.639
# 159        Gambia                              NaN            4.516
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 150         0.05141                   0.46534  0.77115
# 151         0.04324                   0.25812  0.85188
# ...

# %% [markdown]
# This prints out the last 10 rows of our dataset

# %%
happiness.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       160.000000      158.000000                160.000000  158.000000
# mean          5.365756        0.047885                  0.842979    0.991046
# std           1.141280        0.017146                  0.402840    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.517750        0.037268                  0.539453    0.856823
# 50%           5.203000        0.043940                  0.901085    1.029510
# 75%           6.193250        0.052300                  1.155523    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                160.000000  160.000000                     160.000000
# mean                   0.628037    0.428151                       0.143023
# ...

# %% [markdown]
# This shows the statistical properties of the numerical columns of the dataframe

# %%
happiness.isna().sum(axis=0)
# Out:
# Country                          0
# Region                           2
# Happiness Score                  0
# Standard Error                   2
# Economy (GDP per Capita)         0
# Family                           2
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                2
# year                             0
# dtype: int64

# %% [markdown]
# this shows the number of missing enteries

# %%
happiness=happiness.fillna(0)

# %% [markdown]
# Fill in a 0 for any missing values

# %% [markdown]
# # <mark> WFF </mark> Choosing to replace missing values and NaNs with a 0 could be a good choice, but it is a _significant_ choice. Therefore you should definitely justify why you made that choice

# %%
happiness.isna().sum(axis=0)
# Out:
# Country                          0
# Region                           0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# year                             0
# dtype: int64

# %%
happiness.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       160.000000      160.000000                160.000000  160.000000
# mean          5.365756        0.047286                  0.842979    0.978658
# std           1.141280        0.017854                  0.402840    0.292321
# min           2.839000        0.000000                  0.000000    0.000000
# 25%           4.517750        0.036790                  0.539453    0.843633
# 50%           5.203000        0.043805                  0.901085    1.025665
# 75%           6.193250        0.052260                  1.155523    1.210735
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                160.000000  160.000000                     160.000000
# mean                   0.628037    0.428151                       0.143023
# ...

# %% [markdown]
# Now, there are no missing values in any column

# %%
happiestcountry=happiness[happiness["Happiness Score"]==happiness['Happiness Score'].max()]
happiestcountry
# Out:
#        Country          Region  Happiness Score  Standard Error  \
# 0  Switzerland  Western Europe            7.587         0.03411
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 0                        0.41978     0.29678            2.51738  2015

# %%
print("The happiest country in this dataset is " + format(happiestcountry.Country.values[0]))
# Out:
# The happiest country in this dataset is Switzerland

# %%
besteconomy=happiness[happiness["Economy (GDP per Capita)"]==happiness['Economy (GDP per Capita)'].max()]
print("The country with the best Economy in this dataset is " + format(besteconomy.Country.values[0]))
# Out:
# The country with the best Economy in this dataset is Qatar

# %%
Bestfamily=happiness[happiness["Family"]==happiness['Family'].max()]
print("The country with the highest number per Family in this dataset is " + format(Bestfamily.Country.values[0]))
# Out:
# The country with the highest number per Family in this dataset is Iceland

# %%
Besthealth=happiness[happiness["Health (Life Expectancy)"]==happiness['Health (Life Expectancy)'].max()]
print("The country with the best health in this dataset is " + format(Besthealth.Country.values[0]))
# Out:
# The country with the best health in this dataset is Singapore

# %%
Highfreedom=happiness[happiness["Freedom"]==happiness['Freedom'].max()]
print("The country with the highest freedom in this dataset is " + format( Highfreedom.Country.values[0]))
# Out:
# The country with the highest freedom in this dataset is Norway

# %%
HighTrust=happiness[happiness["Trust (Government Corruption)"]==happiness['Trust (Government Corruption)'].max()]
print("The country with the highest freedom in this dataset is " + format( HighTrust.Country.values[0]))
# Out:
# The country with the highest freedom in this dataset is Rwanda

# %%
BestGenerosity=happiness[happiness["Generosity"]==happiness['Generosity'].max()]
print("The country with the Best generosity in this dataset is " + format( BestGenerosity.Country.values[0]))
# Out:
# The country with the Best generosity in this dataset is Myanmar

# %%
highdysto=happiness[happiness["Dystopia Residual"]==happiness['Dystopia Residual'].max()]
print("The country with the highest Dystopia Residual in this dataset is " + format( highdysto.Country.values[0]))
# Out:
# The country with the highest Dystopia Residual in this dataset is Mexico

# %% [markdown]
# This last 8 rows of codes show the country with the highest values for each of the categories. We see that Switzerland, which is the happiest country, doesn't come up as the top country in any other category.

# %%
myhappycountry= happiness[happiness["Country"]=="Australia"]
myhappycountry
# Out:
#      Country                     Region  Happiness Score  Standard Error  \
# 9  Australia  Australia and New Zealand            7.284         0.04083
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 9                   1.33358  1.30923                   0.93156  0.65124
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 9                        0.35637     0.43562            2.26646  2015

# %%
format(myhappycountry.Country.values[0])
# Out:
# 'Australia'

# %%
myhappycountry["Happiness Score"]
# Out:
# 9    7.284
# Name: Happiness Score, dtype: float64

# %% [markdown]
# this is to show the happiness score of my chosen country

# %%
happiness.sort_values("Happiness Score", axis=0, ascending=False, inplace=True)
happiness.head(10)
# Out:
#        Country                     Region  Happiness Score  Standard Error  \
# 0  Switzerland             Western Europe            7.587         0.03411
# 1      Iceland             Western Europe            7.561         0.04884
# 2      Denmark             Western Europe            7.527         0.03328
# 3       Norway             Western Europe            7.522         0.03880
# 4       Canada              North America            7.427         0.03553
# 5      Finland             Western Europe            7.406         0.03140
# 6  Netherlands             Western Europe            7.378         0.02799
# 7       Sweden             Western Europe            7.364         0.03157
# 8  New Zealand  Australia and New Zealand            7.286         0.03371
# 9    Australia  Australia and New Zealand            7.284         0.04083
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# The top 10 happiest countries are : Switzerland, Iceland, Denmark, Norway,Canada, Finland, Netherlands, Sweden, New Zealand, Australia

# %%
happiness.columns
# Out:
# Index(['Country', 'Region', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'year'],
#       dtype='object')

# %%
happiness[['Happiness Score', 'Standard Error',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual', 'year' ]].corr()
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.145332
# Standard Error                       -0.145332        1.000000
# Economy (GDP per Capita)              0.780130       -0.185641
# Family                                0.713057        0.006275
# Health (Life Expectancy)              0.725936       -0.271083
# Freedom                               0.568437       -0.115536
# Trust (Government Corruption)         0.395285       -0.160966
# Generosity                            0.182865       -0.066077
# Dystopia Residual                     0.517173        0.190732
# year                                 -0.077951       -0.298910
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780130  0.713057
# Standard Error                                -0.185641  0.006275
# Economy (GDP per Capita)                       1.000000  0.620515
# ...

# %% [markdown]
# this is the corellation table of the values

# %%
pl.imshow(happiness[['Happiness Score', 'Standard Error',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual', 'year' ]].corr(),)
pl.xticks([0,2,4,6,8], ['Happiness Score', 'Standard Error',
       'Economy(GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual', 'year'],rotation= 70)
pl.yticks([0,2,4,6,8], ['Happiness Score', 'Standard Error',
       'Economy(GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual', 'year'],rotation= 45)
pl.colorbar();

# %% [markdown]
# This diagram is a graph of the correlation between each variable. The yellow spots represent a perfect correlation, a coreelation of 1.
#  From the diagram, It is obvious that the variables have a perfect correlation when compared to themselves, as shown with the yellow diagonal.
#  We see an anti-corrrelation in few boxes where the correlation is negative and displays a deep purple colour.

# %% [markdown]
# # <mark> WFF </mark> In this type of plot, it's important to be able to see which exact feautures correlate with which other features, therefore every row and column should have labels. Here you adeptly only showed the labels for every other row and column, but this lessens the value of this plot.

# %%
happiness.groupby("Region").max().sort_values(by="Generosity", ascending=False)
# Out:
#                                         Country  Happiness Score  \
# Region
# Southeastern Asia                       Vietnam            6.798
# Western Europe                   United Kingdom            7.587
# Sub-Saharan Africa                     Zimbabwe            5.477
# Southern Asia                         Sri Lanka            5.253
# Australia and New Zealand           New Zealand            7.286
# Middle East and Northern Africa           Yemen            7.278
# Latin America and Caribbean           Venezuela            7.226
# North America                     United States            7.427
# Eastern Asia                             Taiwan            6.298
# Central and Eastern Europe           Uzbekistan            6.505
# 0                                       Namibia            4.639
#
#                                  Standard Error  Economy (GDP per Capita)  \
# Region
# Southeastern Asia                       0.06698                   1.52186
# ...

# %% [markdown]
# The region with the higgest generosity is Southern Asia
